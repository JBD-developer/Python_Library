# %% [markdown]
# ##### 1.1 CSV
# - 데이터 값을 , 로 구분하고 있다는 의미로 Comma-Separated-Values 라고 부르는 텍스트 파일이다.
# - 쉼표(,)로 열을 구분하고 줄바꿈으로 행을 구분한다.
# - CSV파일 - Dataframe  : pandas.read_csv("파일 경로(이름)")

# %%
import sys 
import pandas as pd 

file_path = "File\\read_csv_sample.csv"

df1 = pd.read_csv(file_path)
print(df1)
print("\n")
df2 = pd.read_csv(file_path, header=None)
print(df2)
print("\n")
df3 = pd.read_csv(file_path, index_col=None)
print(df3)
print("\n")
df4 = pd.read_csv(file_path, index_col='c0')
print(df4)
# Out:
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9
#
#
#     0   1   2   3
# 0  c0  c1  c2  c3
# 1   0   1   4   7
# 2   1   2   5   8
# 3   2   3   6   9
#
#
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9
#
#
#     c1  c2  c3
# c0
# 0    1   4   7
# 1    2   5   8
# 2    3   6   9

# %% [markdown]
# ##### 1.2 Excel
# - Excel 파일은 행과 열을 Dataframe의 행, 열로 1:1 대응된다.
# - Excel 파일 - Dataframe  : pandas.read_excel("파일 경로(이름)")

# %%
import pandas as pd 

df1 = pd.read_excel("File\\남북한발전전력량.xlsx", engine='openpyxl')
df3 = pd.read_excel("File\\남북한발전전력량.xlsx", engine='openpyxl', header=None)
print(df1)
print("\n")
print(df3)
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %% [markdown]
# ##### 1.3 Json
# - Json 파일은 데이터 공유를 목적으로 개발된 특수한 파일 형식이다.
# - Python dictionary 와 비슷하게 key : value 구조를 갖는데 구조가 중첩되는 방식에 따라 다르게 적용된다.
# - Json 파일 - Dataframe  : pandas.read_json("파일 경로(이름)")

# %%
import pandas as pd 

df = pd.read_json("File\\read_json_sample.json")
print(df)
print("\n")
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %% [markdown]
# #### 2.1 HTML table
# - Pandas read_html() 함수는 HTML 웹페이지에 있는 table 태그에서 표형식의 데이터를 모두 찾아서 Dataframe로 변환한다.
# - 표형식의 데이터들은 각각 별도의 Dataframe으로 변환되기 때문에 여러 개의 Dataframe을 원소로 갖는 리스트가 반환된다.

# %%
import pandas as pd 

url = "File\\sample.html"
tables = pd.read_html(url)
print(len(tables))
print(tables[0])
print(tables[1])

for i in range(len(tables)):
    print("tables[%d]", i)
    print(tables[i])
    print("\n")

df = tables[1]

df.set_index(["name"], inplace=True)
print(df)
# Out:
# 2
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True
# tables[%d] 0
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
#
#
# tables[%d] 1
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True
#
#
#             year        developer  opensource
# name
# NumPy       2006  Travis Oliphant        True
# matplotlib  2003   John D. Hunter        True
# pandas      2008    Wes Mckinneye        True

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas

# url = "https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
url = "https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
resp = requests.get(url)
soup = BeautifulSoup(resp.text, "lxml")
rows = soup.select('div > ul > li')

etfs = []

for row in rows:
    try:
        etf_name = re.findall('^(.*) \  (NYSE', row.text)
        etf_market = re.findall('\((.*)\|', row.text)
        etf_ticker = re.findall('NYSE Arca\|(.*)\)', row.text)
        
        if (len(etf_ticker) > 0 & (len(etf_market) > 0) & len(etf_name) >0 ):
            etfs[etf_ticker[0]] = [etf_market[0], etf_name[0]]
    except AttributeError as err :
        pass 

print(etfs)
print("\n")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# e:\workSpace_Library\Pandas\Ex01\Pandas03.ipynb Cell 9' in <module>
#      <a href='vscode-notebook-cell:/e%3A/workSpace_Library/Pandas/Ex01/Pandas03.ipynb#ch0000008?line=13'>14</a> for row in rows:
#      <a href='vscode-notebook-cell:/e%3A/workSpace_Library/Pandas/Ex01/Pandas03.ipynb#ch0000008?line=14'>15</a>     try:
# ---> <a href='vscode-notebook-cell:/e%3A/workSpace_Library/Pandas/Ex01/Pandas03.ipynb#ch0000008?line=15'>16</a>         etf_name = re.findall('^(.*) (NYSE', row.text)
#      <a href='vscode-notebook-cell:/e%3A/workSpace_Library/Pandas/Ex01/Pandas03.ipynb#ch0000008?line=16'>17</a>         etf_market = re.findall('\((.*)\|', row.text)
#      <a href='vscode-notebook-cell:/e%3A/workSpace_Library/Pandas/Ex01/Pandas03.ipynb#ch0000008?line=17'>18</a>         etf_ticker = re.findall('NYSE Arca\|(.*)\)', row.text)
#
# ...
