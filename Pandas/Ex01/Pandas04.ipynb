# %% [markdown]
# #### Dataframe의 구조
# ##### 01-01. Dataframe 미리보기
# - Dataframe으로 정리된 데이터셋을 처음 접할 때 가장 먼저 head() 메소드이다. Dataframe의 앞부분 일부 내용을 출력한다.
# - 데이터셋의 내용과 구조를 개략적으로 살펴보는 것이 가능하기 때문에 분석 방향을 정하는데 필요한 정보를 얻기 용이하다.
# - Dataframe의 마지막 부분을 보고 싶다면 tail() 메소드를 호출한다.
# - 앞부분 Dataframe.head(n)
# - 뒷부분 Dataframe.tail(n)
# ##### 01-02. 요약 정보 확인하기
# - Dataframe 클래스의 shape 속성은 행과 열의 개수를 튜플 형태로 나타낸다.
# - info() 메소드를 Dataframe에 적용하면 기본 정보를 출력한다.

# %%
import pandas as pd 
pd.set_option('display.max.colwidth', 700)
df = pd.read_csv("File\\auto-mpg.csv", header=None)

df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']

# print(df.head(5))
# print(df.tail(5))
# print(df.shape)
# print(df.info())
# print(df.mpg.dtype)
# print(df.describe(include='all'))
# print(df.count())
# print(df.value_counts())
# unique_values = df['origin'].value_counts()
# print(unique_values)

# %%
import pandas as pd 

# 평균값 mean() 
# 중간값 median()
# 최대값 max()
# 최소값 min() 
# 표준편차 std() 
# 상관계수 corr() 

df = pd.read_csv("File\\auto-mpg.csv", header=None)
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']
print(df.head(5))
print("\n")
print(df["mpg"].mean())
print(df.mpg.mean())
print(df[["mpg", "weight"]].mean())
print("="*30)
print(df.shape)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
#
# 23.514572864321607
# 23.514572864321607
# mpg         23.514573
# weight    2970.424623
# dtype: float64
# ...
# (398, 9)
